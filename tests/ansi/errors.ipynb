# %%
A = [
# Out:
# ParseError:
# # Error @ ]8;;file:///home/j/repos/callisto/tests/ansi/In[1]#1:6\In[1]:1:6]8;;\
# A = [
# #    └ ── premature end of input
#
# Stacktrace:
#  [1] top-level scope
#    @ In[1]:1

# %%
error("x")
# Out:
# x
#
# Stacktrace:
#  [1] error(s::String)
#    @ Base ./error.jl:35
#  [2] top-level scope
#    @ In[2]:1

# %%
sin("d")
# Out:
# MethodError: no method matching sin(::String)
# The function `sin` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   sin(::Missing)
#    @ Base math.jl:1533
#   sin(::Irrational{:π})
#    @ Base mathconstants.jl:146
#   sin(::Float16)
#    @ Base math.jl:1511
#   ...
#
#
# Stacktrace:
#  [1] top-level scope
#    @ In[3]:1

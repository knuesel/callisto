# %%
#| label: sin
sin(1.2)
# Out:
# 0.9320390859672263

# %%
#| label: cos
cos(1.2)
# Out:
# 0.3623577544766736

# %%
#| label: tan
#| fig-cap: Tangent of 1.2
tan(1.2)
# Out:
# 2.5721516221263188

# %%
2+3
# Out:
# 5

# %%
2+4
# Out:
# 6

# %%
#| label: x
a = 1
b = 2
c = a + b
c
# Out:
# 3

# %%
"a" + "b"
# Out:
# 'ab'

# %%
#| output: false
2 + 3
# Out:
# 5

# %%
#| echo: false
10 + 1
# Out:
# 11

# %%
10 + 1
# Out:
# 11

# %%
10 + 2
# Out:
# 12

# %%
10 + 3
# Out:
# 13

# %%
10 + 4
# Out:
# 14

# %%
a = 23; a
# Out:
# 23

# %%
b = 42; b
# Out:
# 42

# %%
3*3
# Out:
# 9

# %%
3*3
# Out:
# 9

# %%
# | label: transform
3*3
# Out:
# 9

# %%
4*4
# Out:
# 16

# %%
5*5
# Out:
# 25

# %%
# | dedup: 2
4*4
# Out:
# 16

# %%
# | dedup: 2
5*5
# Out:
# 25

# %%
from sympy import *
x = symbols('x')

# %%
# | label: 0
2*x**3 + 4*x
# Out:
# 2*x**3 + 4*x

# %%
# | label: 0-diff
diff(2*x**3 + 4*x)
# Out:
# 6*x**2 + 4

# %%
# | label: 1
sin(2*x)
# Out:
# sin(2*x)

# %%
# | label: 1-diff
diff(sin(2*x))
# Out:
# 2*cos(2*x)

# %%
# | label: 2
log(x + 1)
# Out:
# log(x + 1)

# %%
# | label: 2-diff
diff(log(x + 1))
# Out:
# 1/(x + 1)

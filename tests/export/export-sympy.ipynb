# %%
from sympy import *
x = symbols('x')

# %%
3*x**3
# Out:
# 3*x**3

# %%
diff(3*x**3)
# Out:
# 9*x**2

# %%
sin(2*x)
# Out:
# sin(2*x)

# %%
diff(sin(2*x))
# Out:
# 2*cos(2*x)

# %%
log(x + 1)
# Out:
# log(x + 1)

# %%
diff(log(x + 1))
# Out:
# 1/(x + 1)

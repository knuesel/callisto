# %% [markdown]
# # Title
#
# Some text $x^2 = 4$.
#
# $$a^2 + b^2 = c^2$$

# %% [raw]
# A raw cell

# %%
# Make a Markdown display
display("text/markdown", "## Section title\nSome **text**.")
# And a Markdown result
using Markdown
md"More text, with equation $x^2 = -1$."
# Out:
# ## Section title
# Some **text**.
#   More text, with equation x^2 = -1.

# %%
# Make a LaTeX output
using LaTeXStrings
L"\int_a^b f(x)\,dx = \lim_{n\to\infty}\frac{b-a}{n}\sum_{i=1}^n f(x^*)"
# Out:
# L"$\int_a^b f(x)\,dx = \lim_{n\to\infty}\frac{b-a}{n}\sum_{i=1}^n f(x^*)$"

# %%
using CairoMakie
update_theme!(size=(300, 200))

# %%
@show 11
2 + aa  # causes an error
# Out:
# 11 = 11
# UndefVarError: `aa` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[4]:2

# %%
#| label: plot1
#| type: scatter
x = -5:5
scatter(x)

# %%
#| label: plot2
#| type: scatter
display(scatter(x.^2));

# %%
#| label: plot3
#| type: scatter
# | name: pattern-test
a = 2
@show a

CairoMakie.activate!(type="png")
scatter(x.^3) |> display
CairoMakie.activate!(type="svg")
scatter(-x) |> display

@show a+1

a+3
# Out:
# a = 2
# a + 1 = 3
# 5

# %% [markdown]
# Markdown image from file, with link: [![Creative Commons](images/cc.png)](https://creativecommons.org/mission/downloads)

# %% [markdown]
# HTML tag image with `width="100"` (should be small):
# <img src="images/xwidgets.png" width="100"/>

# %% [markdown]
# SVG cell attachment: ![SVG logo](attachment:cc.svg)

# %% [markdown]
# PNG cell attachment: ![PNG logo](attachment:cc.png)

# %% [markdown]
# JPEG cell attachment: ![cc.jpeg](attachment:cc.jpeg)

# %% [markdown]
# A GIF as attachment: ![Bulb](attachment:bulb)

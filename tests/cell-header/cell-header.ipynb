# %% [markdown]
# Input only:

# %%
#| label: only-input
#| output: false
10 + 1
# Out:
# 11

# %% [markdown]
# Output only:

# %%
#| label: only-output
#| echo: false
10 + 2
# Out:
# 12

# %% [markdown]
# Both, neat style:

# %%
#| label: with-neat
#| style: neat
10 + 3
# Out:
# 13

# %% [markdown]
# Both, plain style:

# %%
#| label: with-plain
#| style: plain
10 + 4
# Out:
# 14

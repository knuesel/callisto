# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (3, 2)
plt.plot([1, 2, 3, 4], [1, 4, 9, 16]);

# %%
import sympy as sp
a, b = sp.symbols('a b')
sp.expand((a+b)**2)
# Out:
# a**2 + 2*a*b + b**2
